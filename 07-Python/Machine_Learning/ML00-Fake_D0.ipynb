# %%
import uproot

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import sys

# import plothist
# plt.style.use("belle2")
# from plothist import make_2d_hist, plot_2d_hist_with_projections

# %%
plt.rcParams.update({
    "axes.labelsize": 14,
    "xtick.labelsize": 12,
    "ytick.labelsize": 12,
    "legend.fontsize": 12,
    "figure.titlesize": 16
})

# %%
sys.path.append("/home/belle2/amubarak/Ds2D0enue_Analysis/10-Python_Functions/")

# %% [markdown]
# # Prep-Work

# %% [markdown]
# ### Import Data

# %%
# In this notebook we only process the main signal and the generic events,
# for illustration purposes.
# You can add other backgrounds after if you wish.
samples = ["Signal","All","BB","ccbar","ddbar","ssbar","taupair","uubar","uds"]

# %%
DataFrames = {}  # define empty dictionary to hold dataframes

# Signal:
DataFrames[samples[0]] =  uproot.concatenate("/home/belle2/amubarak/C01-Simulated_Events/Ds2D0enu-Signal.root:Dstree",library='pd')
# Background
for s in samples[1:]: # loop over samples
    DataFrames[s] =  uproot.concatenate("/group/belle2/users2022/amubarak/TopoAna/Completed_TopoAna/TopoAna_"+ s +".root:Dstree",library='pd')

# %%
pd.set_option('display.max_rows', 200000)
pd.set_option('display.max_columns', 200000)

# %% [markdown]
# The line below is to look at the available variables.

# %%
DataFrames["Signal"].columns.tolist()

# %% [markdown]
# ### Setup
# The code below will be used to apply cuts to the data.
# The range of the plots.

# %%
# Electron ID
#-------------------
# DataFrames["Signal"] = DataFrames["Signal"][DataFrames["Signal"]['e_electronID']>=0.95]
# DataFrames["All"] = DataFrames["All"][DataFrames["All"]['e_electronID']>=0.95]
# DataFrames["Signal"] = DataFrames["Signal"][DataFrames["Signal"]['Ds_gammaveto_em_electronID']>=0.95]
# DataFrames["All"] = DataFrames["All"][DataFrames["All"]['Ds_gammaveto_em_electronID']>=0.95]

# Photon Conversion
#-------------------
# DataFrames["Signal"] = DataFrames["Signal"][DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=0.1]
# DataFrames["All"] = DataFrames["All"][DataFrames["All"]['Ds_gammaveto_M_Correction']>=0.1]

# Peaking Background Removal
#----------------------------
# DataFrames["All"] = DataFrames["All"][(DataFrames["All"]['Ds_diff_D0pi']>=0.15)]
# DataFrames["Signal"] = DataFrames["Signal"][(DataFrames["Signal"]['Ds_diff_D0pi']>=0.15)]

# # Vertex Fitting
# #----------------
# DataFrames["Signal"] = DataFrames["Signal"][DataFrames["Signal"]['Ds_chiProb']>=0.01]
# DataFrames["All"] = DataFrames["All"][DataFrames["All"]['Ds_chiProb']>=0.01]

# Dalitz Removal
#----------------------------
# DataFrames["All"] = DataFrames["All"][(DataFrames["All"]['Ds_pi0veto_M_Correction']<=0.08) | (DataFrames["All"]['Ds_pi0veto_M_Correction']>=0.16)]
# DataFrames["Signal"] = DataFrames["Signal"][(DataFrames["Signal"]['Ds_pi0veto_M_Correction']<=0.08) | (DataFrames["Signal"]['Ds_pi0veto_M_Correction']>=0.16)]

# Vertex Fit
#----------------
# DataFrames["Signal"] = DataFrames["Signal"][DataFrames["Signal"]['Ds_chiProb_rank']==1]
# DataFrames["All"] = DataFrames["All"][DataFrames["All"]['Ds_chiProb_rank']==1]

# D0 Invariant Mass
#-----------------------
# DataFrames["Signal"] = DataFrames["Signal"][(DataFrames["Signal"]['Ds_D0_sideband']==1)]
# DataFrames["All"] = DataFrames["All"][(DataFrames["All"]['Ds_D0_sideband']==1)]

# KaonID
#-----------------
# DataFrames["Signal"] = DataFrames["Signal"][DataFrames["Signal"]['K_kaonID']>=0.5]
# DataFrames["All"] = DataFrames["All"][DataFrames["All"]['K_kaonID']>=0.5]

# %%
Norm = False
print(DataFrames["Signal"]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))
print(DataFrames["All"]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))

# %%
DataFrames["ccbar"].isna().sum()

# %% [markdown]
# # Single Variable
# The code below is to look at any specific variable closely.

# %%
Stacked = False
Density = True
Bins = 50
# i = 'D0_dM'
# i = 'D0_cos_decayAngle_1'
# i = 'pi_dr'
# i = "D0_useCMSFrame_p"
# i = 'D0_chiProb'
# i = 'K_dr'
i = 'D0_flightDistance'
# i = 'K_kaonID'
# i = 'pi_pionID'
Range = [-0.2,0.2]
# Range = [-1,1]
# perBin = ((Range[1] - Range[0])/Bins)*1000
perBin = ((Range[1] - Range[0])/Bins)
print("Width Per Bin: {width:.3f} MeV".format(width = perBin))

label1= r'$isSignal(D^{0}) \neq 1$'
label2= r'$isSignal(D^{0})=1$'

labels=[label1,label2]
colors=['purple',"#D55E00"]
data=[
      DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==0) | (DataFrames["All"]['D0_isSignal'].isna())][i],
      DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==1)][i]
     ]

# plt.hist(DataFrames["Signal"][i], label="Signal", color='#7eb0d5',density=Density, bins=Bins, alpha=0.8, range=Range)
plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)

# Title
#--------
# plt.title(r'$D_s^{+} \rightarrow [D^{0} \rightarrow K^{-} \pi^{+}] e^{+} \nu_{e}$', loc = "left")
# plt.title(r'$\int\mathcal{L}dt\approx\;1443.999$ fb$^{-1}$', loc = "right")
# Label
#-------
# plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c)$'.format(width = perBin))
plt.ylabel(r'$Entries/({width:.3f})$'.format(width = perBin))
# plt.xlabel(r'$m(D^{0}) - m_{PDG}(D^{0}) \;[GeV/c^{2}]$')
# plt.xlabel(r'$\cos\theta^*_{\text{daughter}_1}$')
# plt.xlabel(r'$dr(K^{-})\;[cm]$')
# plt.xlabel(r'$dr(\pi^{+})\;[cm]$')
# plt.xlabel(r'$p^{*} (D^{0})\;[GeV/c]$')
# plt.xlabel(r'$p-value(D^{0})$')
plt.xlabel(r'$Flight \; Distance(D^{0}) \; [cm]$')
# plt.xlabel(r'$kaonID(K^{-})$')
# plt.xlabel(r'$pionID(\pi^{+})$')
# plt.yscale("log")
plt.legend()
plt.show()

# %%
Stacked = False
Density = False
Bins = 50
i = 'D0_M'
# Range = [0,0.1]
Range = [1.84484,1.88484]
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

label1= r'$Background$'
label2= r'$Signal$'

labels=[label1,label2]
colors=['#fd7f6f','#7eb0d5']
data=[
      DataFrames["All"][i],
      DataFrames["Signal"][i]
     ]

# plt.hist(DataFrames["Signal"][i], label="Signal", color='#7eb0d5',density=Density, bins=Bins, alpha=0.8, range=Range)
plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)

# Title
#--------
plt.title(r'$D_s^{+} \rightarrow [D^{0} \rightarrow K^{-} \pi^{+}] e^{+} \nu_{e}$', loc = "left")
# Label
#-------
plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
# plt.xlabel(r'$|dr| (K^{-}) \; [cm]$')
plt.xlabel(r'$m(K^{-} \pi^{+})\;[GeV/c^{2}]$')
# plt.xlabel(r'$flight \; Distance \; (K^{-} \pi^{+})$')
# plt.xlabel(r'$cos(Decay \; Angle) \; (K^{-} \pi^{+})$')
# plt.xlabel(r'$Decay \; Angle \; (K^{-} \pi^{+}) \; [rad]$')
# plt.title(r'$electronID: eID\geq 0.1$', loc = "left")
plt.legend()
plt.show()

# %%
Stacked = False
Density = False
Bins = 50
i = "D0_useCMSFrame_p"
# i = "D0_M"
Range = [2.5,5]
# Range = [1.84484,1.88484]
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

label1= r'$Fake \; D^{0}$'
label2= r'$Real \; D^{0}$'

labels=[label1,label2]
colors=['purple',"#D55E00"]
data=[
      DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==0)][i],
      DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==1)][i]
     ]

plt.hist(DataFrames["Signal"][i], label="Signal", color='#7eb0d5',density=Density, bins=Bins, alpha=0.8, range=Range)
plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)

# Title
#--------
plt.title(r'$D_s^{+} \rightarrow [D^{0} \rightarrow K^{-} \pi^{+}] e^{+} \nu_{e}$', loc = "left")
# Label
#-------
plt.ylabel(r'$Entries$')
# plt.xlabel(r'$kaonID (K^{-})$')
# plt.xlabel(r'$p-value (K^{-} \pi^{+})$')
plt.xlabel(r'$p^{*} (K^{-} \pi^{+})\;[GeV/c]$')
# plt.xlabel(r'$\omega (\pi^{+}) \; [cm^{-1}]$')
# plt.xlabel(r'$m(K^{-} \pi^{+})\;[GeV/c^{2}]$')
# plt.xlabel(r'$flight \; Distance \; (K^{-} \pi^{+})$')
# plt.xlabel(r'$cos(Decay \; Angle) \; (K^{-} \pi^{+})$')
# plt.xlabel(r'$Decay \; Angle \; (K^{-} \pi^{+}) \; [rad]$')
# plt.title(r'$electronID: eID\geq 0.1$', loc = "left")
plt.legend()
plt.show()

# %% [markdown]
# # Multiple Variable

# %%
# features = DataFrames["All"].columns.tolist()

# Suffix removal from String list
# using list comprehension + endswith()
# features = [ele for ele in features if not ele.endswith('acoplanarityAngle')
#             and not ele.endswith('goodDsplus')
#             ]

# %%
# Stacked = False
# Density = True
# Bins = 50

# # label1= 'failed'
# # label2= r'$e^{+}\;\mathrm{from}\;\gamma$'
# # label3= r'$e^{+}\;\mathrm{from}\;\pi^{0}$'
# # label4= 'misID'

# for i in features:
#     Range = [DataFrames['Signal'][i].min(axis=0),DataFrames['Signal'][i].max(axis=0)]

#     label1= r'$Fake \; D^{0}$'
#     label2= r'$Real \; D^{0}$'

#     labels=[label1,label2]
#     colors=['purple',"#D55E00"]
#     data=[
#     DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==0)][i],
#     DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==1)][i]
#     ]

#     plt.hist(DataFrames["Signal"][i], label="Signal", color='#7eb0d5',density=Density, bins=Bins, alpha=0.8, range=Range)
#     plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)

#     plt.ylabel('Entries')
#     plt.xlabel(i)
#     plt.yscale("log")
#     plt.legend()
#     plt.show()

# %% [markdown]
# # Background

# %%
Stacked = False
Density = False
Bins = 50
i = 'Ds_diff_D0pi'
# i = 'Ds_massDifference_0'
Range = [0.1, 0.8]
Op = 0.58
dM = 0.1
Hits = 0
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

RE = (len(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["Signal"]['e_nPXDHits']>Hits) & (DataFrames["Signal"]["Ds_extraInfo_FastBDT"]>=Op)])/(2000000))*100

label1= r'$other$'
label2= r'$Comb.$'
label3= r'$NaN$'
label4= r'$D^{*0}$'
label5= r'$D^{*+} \rightarrow D^{0} \pi^{+}$'

labels=[label1,label2,label3,label4,label5]
colors=['C2','C1','C3','C4','C5']
data=[
      DataFrames["All"][(abs(DataFrames["All"]["Ds_Other"])==1) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==23) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna()) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==423) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==413) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i]
      ]

factor = 0.25
plt.hist(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["Signal"]['e_nPXDHits']>Hits) & (DataFrames["Signal"]["Ds_extraInfo_FastBDT"]>=Op)][i], label="Signal", histtype='step', density=Density, bins=Bins, alpha=1, range=Range, weights=factor*np.ones_like(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["Signal"]['e_nPXDHits']>Hits) & (DataFrames["Signal"]["Ds_extraInfo_FastBDT"]>=Op)][i]), ls='--', linewidth=1.5)
plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)
# plt.axvspan(Range[0],0.15,color='gray',alpha=0.2)
# plt.axvline(0.15,ls='--',color='gray')

# Title
#--------
# plt.title(r'$nPXDHits(e^{+})>0$', loc = "left")
# plt.title(r'$BDT \geq 0.58$', loc = "left")
plt.title(r'$nPXDHits(e^{+})>0$'+'\n'+r'$BDT \geq 0.58$', loc = "left")
plt.title('Reconstruction Efficiency:{eff:.2f}%'.format(eff = RE), loc = "Right")
# Label
#-------
plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
plt.xlabel(r'$\Delta m(D_s^{+} - D^{0})\;[GeV/c^{2}]$')
# plt.yscale("log")
# plt.xscale("log")
plt.ylim(0, 2100)
plt.legend(bbox_to_anchor=(1.04, 1), borderaxespad=0)
plt.show()

RE = len(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["Signal"]['e_nPXDHits']>Hits) & (DataFrames["Signal"]["Ds_extraInfo_FastBDT"]>=Op)])/(2000000)

# %%
# Stacked = True
# Density = False
# Bins = 50
# i = 'Ds_diff_D0pi'
# Range = [0.1,1]
# dM = 0.1
# D = 1
# perBin = ((Range[1] - Range[0])/Bins)*1000
# print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

# label1= r'$other$'
# label2= r'$combinatoric$'
# label3= r'$failed$'
# label4= r'$D^{*0}$'
# label5= r'$D^{*+} \rightarrow D^{0} \pi^{+}$'

# labels=[label1,label2,label3,label4,label5]
# colors=['C2','C1','C3','C4','C5']
# data=[DataFrames["All"][(abs(DataFrames["All"]["Ds_Other"])==1) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["All"]['D0_isSignal'])==D)][i],
#       DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==23) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["All"]['D0_isSignal'])==D)][i],
#       DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna()) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["All"]['D0_isSignal'])==D)][i],
#       DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==423) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["All"]['D0_isSignal'])==D)][i],
#       DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==413) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["All"]['D0_isSignal'])==D)][i]
#       ]

# factor = 1
# plt.hist(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["Signal"]['D0_isSignal'])==D)][i], label="Signal", histtype='step', density=Density, bins=Bins, alpha=1, range=Range, weights=factor*np.ones_like(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["Signal"]['D0_isSignal'])==D)][i]), ls='--', linewidth=1.5)
# plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)
# # plt.axvspan(Range[0],0.15,color='gray',alpha=0.2)
# # plt.axvline(0.15,ls='--',color='gray')

# # Title
# #--------
# plt.title(r'$Real \; D^{0}$', loc = "left")
# # Label
# #-------
# plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
# # plt.xlabel(r'$\Delta m(D_s^{+} - D^{0})\;[GeV/c^{2}]$')
# plt.xlabel(r'$m(K^{-} \pi^{+})\;[GeV/c^{2}]$')
# # plt.yscale("log")
# # plt.xscale("log")
# # plt.ylim(0,70000)
# plt.legend()
# plt.show()

# %%
# print(DataFrames["Signal"]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))
# print(DataFrames["All"][(DataFrames["All"]["Ds_Dstarplus"]==1)]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))
# print(DataFrames["All"][(DataFrames["All"]["Ds_Dstar0"]==1)]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))
# print(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna())]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))
# print(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==23)]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))
# print(DataFrames["All"][(abs(DataFrames["All"]["Ds_Other"])==1)]['D0_isSignal'].value_counts(normalize=Norm,dropna=False))

# %% [markdown]
# # Truth-Matching

# %%
# print(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna())]['pi_isSignal'].value_counts(normalize=False,dropna=False))
# print(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna())]['K_isSignal'].value_counts(normalize=False,dropna=False))
# print(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna())]['e_isSignal'].value_counts(normalize=False,dropna=False))
# print(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna())]['D0_isSignal'].value_counts(normalize=False,dropna=False))
# print(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna())]['Ds_isSignal'].value_counts(normalize=False,dropna=False))

# %%
# print(DataFrames["ccbar"][(abs(DataFrames["ccbar"]['D0_isSignal'])==0)]['pi_genMotherPDG'].value_counts(normalize=False,dropna=False))
# print(DataFrames["ccbar"][(abs(DataFrames["ccbar"]['D0_isSignal'])==0)]['K_genMotherPDG'].value_counts(normalize=False,dropna=False))

# %%
# Check = ['__event__',"pi_p","K_p","D0_p"]

# %%
# DataFrames["ccbar"][(abs(DataFrames["ccbar"]['D0_isSignal'])==0)][Check].head(100)

# %% [markdown]
# # Machine Learning

# %%
Stacked = False
Density = True
Bins = 50
i = "Ds_extraInfo_FastBDT"
# i = 'Ds_massDifference_0'
Range = [0, 1]
dM = 0.1
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

label1= r'$Real \; D^{0}$'
label2= r'$Fake \; D^{0}$'

labels=[label1,label2]
colors=["#D55E00",'purple']
data=[
    DataFrames["All"][(DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["All"]['D0_isSignal'])==1)][i],
    DataFrames["All"][(DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (abs(DataFrames["All"]['D0_isSignal'])==0)][i],
      ]

plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)
# plt.axvspan(Range[0],0.5,color='gray',alpha=0.2)
# plt.axvline(0.5,ls='--',color='gray')

# Background
#-------------
plt.title(r'$\int\mathcal{L}dt\approx\;100$ fb$^{-1}$', loc = "left")
plt.title(r'$\bf Generic\;c\bar{c}\;Events$', loc = "right")
# Label
#-------
# plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
plt.ylabel(r'$Entries$')
# plt.xlabel(r'$\Delta m(D_s^{+} - D^{0})\;[GeV/c^{2}]$')
plt.xlabel('Classifier Output')
# plt.yscale("log")
# plt.xscale("log")
# plt.ylim(0,70000)
plt.legend()
plt.show()

# %%
Stacked = True
Density = False
Bins = 50
i = 'Ds_diff_D0pi'
# i = 'Ds_massDifference_0'
Range = [0.1, 1]
dM = 0.1
Op = -1
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

label1= r'$other$'
label2= r'$combinatoric$'
label3= r'$failed$'
label4= r'$D^{*0}$'
label5= r'$D^{*+} \rightarrow D^{0} \pi^{+}$'

labels=[label1,label2,label3,label4,label5]
colors=['C2','C1','C3','C4','C5']
data=[DataFrames["All"][(abs(DataFrames["All"]["Ds_Other"])==1) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==23) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna()) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==423) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==413) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i]
      ]

factor = 1
plt.hist(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i], label="Signal", histtype='step', density=Density, bins=Bins, alpha=1, range=Range, weights=factor*np.ones_like(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i]), ls='--', linewidth=1.5)
plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)
# plt.axvspan(Range[0],0.15,color='gray',alpha=0.2)
# plt.axvline(0.15,ls='--',color='gray')

# Background
#-------------
plt.title(r'$\int\mathcal{L}dt\approx\;100$ fb$^{-1}$', loc = "left")
plt.title(r'$\bf Generic\;c\bar{c}\;Events$', loc = "right")
# Label
#-------
plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
# plt.xlabel(r'$\Delta m(D_s^{+} - D^{0})\;[GeV/c^{2}]$')
plt.xlabel(r'$m(K^{-} \pi^{+})\;[GeV/c^{2}]$')
# plt.yscale("log")
# plt.xscale("log")
# plt.ylim(0,70000)
plt.legend()
plt.show()

# %%
Op = -1
print("Background",(len(DataFrames["All"][(DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op) & (abs(DataFrames["All"]['D0_isSignal'])==0)])/len(DataFrames["All"][(DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]))*100)
print("Signal",(len(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["Signal"]["Ds_extraInfo_FastBDT"]>=Op) & (abs(DataFrames["Signal"]['D0_isSignal'])==0)])/len(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["Signal"]["Ds_extraInfo_FastBDT"]>=Op)]))*100)

# %%
Op = 0.58
Hits = 0
dM = 0.1
print("D*+",   (len(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==413) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op) & (abs(DataFrames["All"]['D0_isSignal'])==0)])/len(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==413) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]))*100)
print("D*0",   (len(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==423) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op) & (abs(DataFrames["All"]['D0_isSignal'])==0)])/len(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==423) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]))*100)
print("failed",(len(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna()) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op) & (abs(DataFrames["All"]['D0_isSignal'])==0)])/len(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna()) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]))*100)
print("Comb.", (len(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==23) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op) & (abs(DataFrames["All"]['D0_isSignal'])==0)])/len(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==23) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]))*100)
print("Other", (len(DataFrames["All"][(abs(DataFrames["All"]["Ds_Other"])==1) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op) & (abs(DataFrames["All"]['D0_isSignal'])==0)])/len(DataFrames["All"][(abs(DataFrames["All"]["Ds_Other"])==1) &(DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['e_nPXDHits']>Hits) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]))*100)

# %%
print(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==413) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]['D0_isSignal'].value_counts(normalize=False,dropna=False))
print(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==423) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]['D0_isSignal'].value_counts(normalize=False,dropna=False))
print(DataFrames["All"][(DataFrames["All"]["Ds_mcPDG"].isna()) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]['D0_isSignal'].value_counts(normalize=False,dropna=False))
print(DataFrames["All"][(abs(DataFrames["All"]["Ds_mcPDG"])==23) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]['D0_isSignal'].value_counts(normalize=False,dropna=False))
print(DataFrames["All"][(abs(DataFrames["All"]["Ds_Other"])==1) & (DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)]['D0_isSignal'].value_counts(normalize=False,dropna=False))

# %%
from Functions import get_df_sig_bkg,get_nsig_nbkg,plot_var_sig_bkg,optimize_SB,plot_save

optimize_SB(df_sig=DataFrames["Signal"],
            df_bkg=DataFrames["All"],
            var="Ds_extraInfo_FastBDT",
            Signal=DataFrames["Signal"][(DataFrames["Signal"]['Ds_diff_D0pi']<=0.3)],
            Background=DataFrames["All"][(DataFrames["All"]['Ds_diff_D0pi']<=0.3)],
            FoM="Ds_extraInfo_FastBDT",
            xlabel='Classifier Output',
            Bins=50,Range=[0,1],
            varmin=0,varmax=0.98,select='right',Width=False)

# %%
from Functions import get_df_sig_bkg,get_nsig_nbkg,plot_var_Real_Fake,optimize_RF,plot_save

optimize_RF(df_sig=DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==1)],
            df_bkg=DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==0)],
            var="Ds_extraInfo_FastBDT",
            Signal=DataFrames["Test"][(DataFrames["Test"]['C02__miMVA__slCompleted__slMVAFastBDT__ptxml_D0_isSignal']==1)],
            Background=DataFrames["Test"][(DataFrames["Test"]['C02__miMVA__slCompleted__slMVAFastBDT__ptxml_D0_isSignal']==0)],
            FoM='C02__miMVA__slCompleted__slMVAFastBDT__ptxml',
            xlabel='Classifier Output',
            Bins=50,Range=[0,1],
            varmin=0,varmax=0.98,select='right',Width=False)

# %%
C = (200*(10**(15)))*(1.329*(10**(-9)))*2*(0.10)*(3*(10**(-8)))*(0.04)*(1/2000000)

# %%
nsig = C*len(DataFrames["Signal"][(abs(DataFrames["Signal"]['Ds_isSignal'])==1) & (DataFrames["Signal"]['Ds_diff_D0pi']<=0.3)].query('Ds_extraInfo_FastBDT>=0.180'))
nbkg = len(DataFrames["All"][(DataFrames["All"]['Ds_diff_D0pi']<=0.3)].query('Ds_extraInfo_FastBDT>=0.180'))

# %%
print((nsig)/(np.sqrt(nbkg + nsig)))

# %%
print("Signal",len(DataFrames["Signal"][(DataFrames["Signal"]['Ds_diff_D0pi']<=0.3)].query('Ds_extraInfo_FastBDT>=0.0')))
print("Background",len(DataFrames["All"][(DataFrames["All"]['Ds_diff_D0pi']<=0.3)].query('Ds_extraInfo_FastBDT>=0.0')))

# %%
# from FoM import get_df_sig_bkg,get_nsig_nbkg,plot_var_sig_bkg,optimize,plot_save

# optimize(df_sig=DataFrames["All"][(abs(DataFrames["All"]['C02__miMVA__slCompleted__slMVAFastBDT__ptxml_D0_isSignal'])==1)],
#          df_bkg=DataFrames["All"][(abs(DataFrames["All"]['C02__miMVA__slCompleted__slMVAFastBDT__ptxml_D0_isSignal'])==0)],
#          var='C02__miMVA__slCompleted__slMVAFastBDT__ptxml',
#          xlabel='Classifier Output',
#          Bins=50,Range=[0,1],
#          varmin=0.01,varmax=0.985,select='right',Width=False)

# %%
xrange_min = 0
xrange_max = 1
num_bins = 50
bin_width = ((xrange_max - xrange_min)/num_bins)
bin_edges = [ xrange_min + x*bin_width for x in range(num_bins+1) ] # bin limits
FOM = []

for i in range(len(bin_edges)-1):
    # # Each Bin
    # Signal = DataFrames["Signal"][(DataFrames["Signal"]['gammaveto_M']>=bin_edges[i]) & (DataFrames["Signal"]['gammaveto_M']<=bin_edges[i+1])].shape[0]
    # Background = DataFrames["ccbar"][(DataFrames["ccbar"]['gammaveto_M']>=bin_edges[i]) & (DataFrames["ccbar"]['gammaveto_M']<=bin_edges[i+1])].shape[0]
    # Not Bin Focused
    Signal = DataFrames["ccbar"][(abs(DataFrames["ccbar"]['D0_isSignal'])==1) & (DataFrames["Signal"]["Ds_extraInfo_FastBDT"]>=bin_edges[i])].shape[0]
    Background = DataFrames["ccbar"][(abs(DataFrames["ccbar"]['D0_isSignal'])==0) & (DataFrames["ccbar"]["Ds_extraInfo_FastBDT"]>=bin_edges[i])].shape[0]

    FOM_num = (Signal)/((Signal+Background)**(1/2))
    FOM.append(FOM_num)

plt.plot(bin_edges[1:], FOM)
plt.ylabel('FoM')
plt.yscale("log")
plt.ylim(10e1, 0.5*10e2)
plt.xlabel(r'$m(e^{+}e^{-})\;[GeV/c^{2}]$')
plt.show()

# %%
Stacked = False
Density = False
Bins = 50
i = 'D0_M'
# i = 'Ds_massDifference_0'
Range = [1.84484,1.88484]
dM = 0.1
Op = 0.58
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

label1= r'$other$'
label2= r'$combinatoric$'
data=[
      DataFrames["All"][(DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]['D0_isSignal']==1)][i],
      DataFrames["All"][(DataFrames["All"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      ]

plt.hist(data[0], 
         color='C2', 
         label=r'$Cut:isSignal(D^{0})=1$', 
         density=Density, 
         stacked=Stacked, 
         bins=Bins, alpha=1, 
         histtype='step', linewidth=1.5, range=Range)
plt.hist(data[1], 
         color='C1', 
         label=r'$Cut:BDT \geq 0.58$', 
         density=Density, 
         stacked=Stacked, 
         bins=Bins, alpha=1, 
         histtype='step', linewidth=1.5, range=Range)
# plt.axvspan(Range[0],0.15,color='gray',alpha=0.2)
# plt.axvline(0.15,ls='--',color='gray')

# Background
#-------------
plt.title(r'$\int\mathcal{L}dt\approx\;100$ fb$^{-1}$', loc = "left")
plt.title(r'$\bf Generic\;Events$', loc = "right")
# Label
#-------
plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
# plt.xlabel(r'$\Delta m(D_s^{+} - D^{0})\;[GeV/c^{2}]$')
plt.xlabel(r'$m(K^{-} \pi^{+})\;[GeV/c^{2}]$')
# plt.yscale("log")
# plt.xscale("log")
# plt.ylim(0,70000)
plt.legend()
plt.show()

# %%
Stacked = False
Density = False
Bins = 50
i = 'Ds_diff_D0pi'
Range = [0.1,1]
# Range = [1.84484,1.88484]
Op = 0.58
dM = 0.1
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

label1= r'$Fake \; D^{0}$'
label2= r'$Real \; D^{0}$'

labels=[label1,label2]
colors=['purple',"#D55E00"]
data=[
      DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==0) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i],
      DataFrames["All"][(abs(DataFrames["All"]['D0_isSignal'])==1) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i]
     ]

factor = 0.4
plt.hist(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i], label="Signal", histtype='step', density=Density, bins=Bins, alpha=1, range=Range, weights=factor*np.ones_like(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM) & (DataFrames["All"]["Ds_extraInfo_FastBDT"]>=Op)][i]), ls='--', linewidth=1.5)
plt.hist(data, color=colors, label=labels, density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)

# Title
#-------------
plt.title(r'$BDT \geq 0.58$', loc = "left")
# plt.title(r'$\int\mathcal{L}dt\approx\;100$ fb$^{-1}$', loc = "left")
plt.title(r'$\bf Generic\;Events$', loc = "right")
# Label
#-------
plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
plt.xlabel(r'$\Delta m(D_s^{+} - D^{0})\;[GeV/c^{2}]$')
# plt.xlabel(r'$m(K^{-} \pi^{+})\;[GeV/c^{2}]$')
# plt.xlabel(r'$flight \; Distance \; (K^{-} \pi^{+})$')
# plt.xlabel(r'$cos(Decay \; Angle) \; (K^{-} \pi^{+})$')
# plt.xlabel(r'$Decay \; Angle \; (K^{-} \pi^{+}) \; [rad]$')
# plt.title(r'$electronID: eID\geq 0.1$', loc = "left")
plt.ylim(0,15000)
plt.legend()
plt.show()

# %% [markdown]
# # Backgrounds

# %%
Stacked = True
Density = False
Bins = 50
i = 'D0_dM'
# i = 'Ds_massDifference_0'
Range = [-0.02,0.02]
dM = 0.1
perBin = ((Range[1] - Range[0])/Bins)*1000
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

label1= r'$c \bar{c}$'
label2= r'$B^{+} B^{-}$'
label3= r'$B^{0} \bar{B^{0}}$'
label4= r'$u \bar{u}, \; d \bar{d}, \;s \bar{s}$'

labels=[label1,label2,label3,label4]
# colors=['C2','C1','C3','C4','C5']
data=[DataFrames["ccbar"][(DataFrames["ccbar"]['Ds_gammaveto_M_Correction']>=dM)][i],
      DataFrames["charged"][(DataFrames["charged"]['Ds_gammaveto_M_Correction']>=dM)][i],
      DataFrames["mixed"][(DataFrames["mixed"]['Ds_gammaveto_M_Correction']>=dM)][i],
      DataFrames["uds"][(DataFrames["uds"]['Ds_gammaveto_M_Correction']>=dM)][i],
      ]

factor = 0.5
plt.hist(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM)][i], label="Signal", histtype='step', density=Density, bins=Bins, alpha=1, range=Range, weights=factor*np.ones_like(DataFrames["Signal"][(DataFrames["Signal"]['Ds_gammaveto_M_Correction']>=dM)][i]), ls='--', linewidth=1.5)
plt.hist(data[::-1], label=labels[::-1], density=Density, stacked=Stacked, bins=Bins, alpha=1, histtype='step', linewidth=1.5, range=Range)
# plt.axvspan(Range[0],0.15,color='gray',alpha=0.2)
# plt.axvline(0.15,ls='--',color='gray')

# Title
#--------
# plt.title(r'$BCS: Vertex \; Fit \; \chi^{2}$', loc = "left")
plt.title(r'$D_s^{+} \rightarrow [D^{0} \rightarrow K^{-} \pi^{+}] e^{+} \nu_{e}$', loc = "left")
# Label
#-------
plt.ylabel(r'$Entries/(\; {width:.2f}\;MeV/c^2)$'.format(width = perBin))
plt.xlabel(r'$dM(D^{0})\;[GeV/c^{2}]$')
# plt.yscale("log")
# plt.xscale("log")
# plt.ylim(10e1, 10e4)
plt.legend()
plt.show()

# %% [markdown]
# # 2-D Histogram

# %%
# # name_x = 'Ds_massDifference_0'
# name_x = 'Ds_dM_D0pi'
# name_y = 'Ds_Angle_D0e'
# Sample = "ccbar"

# h = make_2d_hist([DataFrames[Sample][name_x], DataFrames[Sample][name_y]], bins=[50, 50], range=[[0.135,0.4],[0,3.14]])

# (
#     fig,
#     ax_2d,
#     ax_x_projection,
#     ax_y_projection,
#     ax_colorbar,
# ) = plot_2d_hist_with_projections(
#     h,
#     xlabel=r'$\Delta m\;[GeV/c^{2}]$',
#     ylabel=r'$\theta(D^{0}e^{+})\;[rad]$',
#     ylabel_x_projection="Entries",
#     xlabel_y_projection="Entries",
#     offset_x_labels=True,
#     colorbar_kwargs={"label": "Entries"},
#     figsize=(6,6)
# )
