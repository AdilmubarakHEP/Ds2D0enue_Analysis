# %%
import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Data

# %%
K = uproot.open("C:/Users/Adilm/Desktop/High_Energy_Physics/Analysis_Code/KEKCC_File/Strange_Count.root:KMCtree").arrays(library='pd')
KS = uproot.open("C:/Users/Adilm/Desktop/High_Energy_Physics/Analysis_Code/KEKCC_File/Strange_Count.root:KSMCtree").arrays(library='pd')

# %% [markdown]
# The line below is to look at the available variables.

# %%
print(K.columns.tolist())

# %% [markdown]
# ### Setup
# The code below will be used to apply cuts to the data.
# The range of the plots.

# %% [markdown]
# ### Mother PDG

# %%
print(K['genMotherPDG'].value_counts(dropna=False))

# %%
K.shape[0]

# %%
print(KS['genMotherPDG'].value_counts(dropna=False))

# %%
KS.shape[0]

# %%
K.shape[0] + KS.shape[0]
