# %%
import uproot
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Import Data

# %%
file = uproot.open("C:/Users/Adilm/Desktop/High_Energy_Physics/Analysis_Code/KEKCC_File/D_s+_Truth.root")

# %%
print(file.keys())

# %%
df = uproot.open("C:/Users/Adilm/Desktop/High_Energy_Physics/Analysis_Code/KEKCC_File/D_s+_Truth.root:D_s+MCtree").arrays(library='pd')

# %% [markdown]
# The line below is to look at the available variables.

# %%
print(df.columns.tolist())

# %%
pd.set_option('display.max_rows', 10000)
pd.set_option('display.max_columns', 10000)

# %% [markdown]
# ### Plots

# %%
Event = ['__experiment__', '__run__', '__event__', '__production__', '__candidate__', '__ncandidates__','mcPDG']
df[df['__ncandidates__']==2][Event].head(300)

# %%
Bins=50
Density = False
Range = [0,5]
perBin = ((Range[1] - Range[0])/Bins)*1000
var = '__ncandidates__'
print("Width Per Bin: {width:.2f} MeV".format(width = perBin))

plt.hist(df[var], label="", alpha=0.9, range=Range, density=Density, bins=Bins)

# Signal
#---------
plt.title(r'$2M\;Events$', loc = "left")
plt.title(r'$\boldsymbol{Signal\;Events}$', loc = "right")
# Label
#---------
plt.ylabel('Entries')
plt.xlabel('# of Candidate/Event')
plt.show()
