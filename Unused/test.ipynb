# %%
import uproot

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# plt.style.use("belle2")

import seaborn as sns

import sys

# import plothist
# plt.style.use("belle2")
# from plothist import make_2d_hist, plot_2d_hist_with_projections

# %% [markdown]
# # Prep-Work

# %% [markdown]
# ### Import Data

# %%
DataFrames = {}  # define empty dictionary to hold dataframes

# Background
DataFrames["Dstar0"] =  uproot.concatenate("/home/belle2/amubarak/C03-Grid/TopoAna.root:Dstar0",library='pd')
DataFrames["D0"] =  uproot.concatenate("/home/belle2/amubarak/C03-Grid/TopoAna.root:D0",library='pd')
DataFrames["Dstarplus"] =  uproot.concatenate("/home/belle2/amubarak/C03-Grid/TopoAna.root:Dstarplus",library='pd')
DataFrames["FakeD0"] =  uproot.concatenate("/home/belle2/amubarak/C03-Grid/TopoAna.root:FakeD0",library='pd')
DataFrames["ccbar"] =  uproot.concatenate("/group/belle2/users2022/amubarak/02-Grid/Completed_TopoAna/Ds2D0e-Generic_Ds_021325_2_ccbar.root:Dstree",library='pd')

# %%
print(len(DataFrames["Dstar0"]) + len(DataFrames["D0"]) + len(DataFrames["Dstarplus"]) + len(DataFrames["FakeD0"]))
print(len(DataFrames["ccbar"]))
